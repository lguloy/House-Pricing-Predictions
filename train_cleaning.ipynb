# %%
import pandas as pd

# %%
csv_file = '../Resources/train.csv'
csv_file
# Out:
# '../Resources/train.csv'

# %%
train_df = pd.read_csv(csv_file)
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# get dummies
# MSZoning_dummies = pd.get_dummies(train_df.MSZoning, prefix='MSZoning').iloc[:, 1:]
# MSZoning_dummies.head()

# %%
for col in train_df.columns:
    print(col)
# Out:
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# TotRmsAbvGrd
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# ...

# %%
# Passing dataframe in to Get dummies for non hierarchical variables 
train_df = pd.get_dummies(train_df, columns=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','Neighborhood', 'Condition1', 'Condition2','BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', 'PavedDrive', 'MiscFeature', 'SaleType', 'SaleCondition'], drop_first=True) 
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea ExterQual  ... SaleType_ConLI SaleType_ConLw  \
# 0          2003       196.0        Gd  ...              0              0
# 1          1976         0.0        TA  ...              0              0
# 2          2002       162.0        Gd  ...              0              0
# 3          1970         0.0        TA  ...              0              0
# 4          2000       350.0        Gd  ...              0              0
#
# ...

# %% [markdown]
# # Hirachial variables
# ExterQual
# ExterCond
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# HeatingQC
# KitchenQual
# Functional
# FireplaceQu
# GarageFinish
# GarageQual
# GarageCond
# Fence

# %%
train_df.value_counts('ExterQual')
# Out:
# ExterQual
# TA    906
# Gd    488
# Ex     52
# Fa     14
# dtype: int64

# %%
# formatting  ['ExterQual'] to Hirachial value 
train_df['ExterQual'] = train_df['ExterQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ... SaleType_ConLI SaleType_ConLw  \
# 0          2003       196.0          4  ...              0              0
# 1          1976         0.0          3  ...              0              0
# 2          2002       162.0          4  ...              0              0
# 3          1970         0.0          3  ...              0              0
# 4          2000       350.0          4  ...              0              0
#
# ...

# %%
# replace testing 
train_df.value_counts('ExterQual')
# Out:
# ExterQual
# 3    906
# 4    488
# 5     52
# 2     14
# dtype: int64

# %%
# formatting  ['ExterCond'] to Hirachial value 
train_df['ExterCond'] = train_df['ExterCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI SaleType_ConLw  \
# 0          2003       196.0          4  ...               0              0
# 1          1976         0.0          3  ...               0              0
# 2          2002       162.0          4  ...               0              0
# 3          1970         0.0          3  ...               0              0
# 4          2000       350.0          4  ...               0              0
#
# ...

# %%
# replace testing 
train_df.value_counts('ExterCond')
# Out:
# ExterCond
# 3    1282
# 4     146
# 2      28
# 5       3
# 1       1
# dtype: int64

# %%
# formatting  ['BsmtQual'] to Hirachial value 
train_df['BsmtQual'] = train_df['BsmtQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1, 'NaN':0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtQual')
# Out:
# BsmtQual
# 3.0    649
# 4.0    618
# 5.0    121
# 2.0     35
# dtype: int64

# %%
# formatting  ['BsmtCond'] to Hirachial value 
train_df['BsmtCond'] = train_df['BsmtCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1, 'NaN':0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtCond')
# Out:
# BsmtCond
# 3.0    1311
# 4.0      65
# 2.0      45
# 1.0       2
# dtype: int64

# %%
# formatting  ['BsmtExposure'] to Hirachial value 
train_df['BsmtExposure'] = train_df['BsmtExposure'].replace({'Gd': 4, 'Av': 3, 'Mn': 2, 'No': 1, 'NaN':0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtExposure')
# Out:
# BsmtExposure
# 1.0    953
# 3.0    221
# 4.0    134
# 2.0    114
# dtype: int64

# %%
# formatting  ['BsmtFinType1'] to Hirachial value 
train_df['BsmtFinType1'] = train_df['BsmtFinType1'].replace({'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ':2, 'Unf': 1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtFinType1')
# Out:
# BsmtFinType1
# 1.0    430
# 6.0    418
# 5.0    220
# 4.0    148
# 3.0    133
# 2.0     74
# dtype: int64

# %%
# formatting  ['BsmtFinType2'] to Hirachial value 
train_df['BsmtFinType2'] = train_df['BsmtFinType2'].replace({'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ':2, 'Unf': 1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtFinType2')
# Out:
# BsmtFinType2
# 1.0    1256
# 3.0      54
# 2.0      46
# 4.0      33
# 5.0      19
# 6.0      14
# dtype: int64

# %%
# formatting  ['HeatingQC'] to Hirachial value 
train_df['HeatingQC'] = train_df['HeatingQC'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('HeatingQC')
# Out:
# HeatingQC
# 5    741
# 3    428
# 4    241
# 2     49
# 1      1
# dtype: int64

# %%
# formatting  ['KitchenQual'] to Hirachial value 
train_df['KitchenQual'] = train_df['KitchenQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('KitchenQual')
# Out:
# KitchenQual
# 3    735
# 4    586
# 5    100
# 2     39
# dtype: int64

# %%
# formatting  ['Functional'] to Hirachial value 
train_df['Functional'] = train_df['Functional'].replace({'Typ': 8, 'Min1': 7, 'Min2': 6, 'Mod': 5, 'Maj1': 4, 'Maj2': 3 , 'Sev': 2, 'Sal': 1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('Functional')
# Out:
# Functional
# 8    1360
# 6      34
# 7      31
# 5      15
# 4      14
# 3       5
# 2       1
# dtype: int64

# %%
# formatting  ['FireplaceQu'] to Hirachial value 
train_df['FireplaceQu'] = train_df['FireplaceQu'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('FireplaceQu')
# Out:
# FireplaceQu
# 4.0    380
# 3.0    313
# 2.0     33
# 5.0     24
# 1.0     20
# dtype: int64

# %%
# formatting  ['GarageFinish'] to Hirachial value 
train_df['GarageFinish'] = train_df['GarageFinish'].replace({'Fin': 3, 'RFn': 2, 'Unf': 1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('GarageFinish')
# Out:
# GarageFinish
# 1.0    605
# 2.0    422
# 3.0    352
# dtype: int64

# %%
# formatting  ['GarageQual'] to Hirachial value 
train_df['GarageQual'] = train_df['GarageQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('GarageQual')
# Out:
# GarageQual
# 3.0    1311
# 2.0      48
# 4.0      14
# 5.0       3
# 1.0       3
# dtype: int64

# %%
# formatting  ['GarageCond'] to Hirachial value 
train_df['GarageCond'] = train_df['GarageCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('GarageCond')
# Out:
# GarageCond
# 3.0    1326
# 2.0      35
# 4.0       9
# 1.0       7
# 5.0       2
# dtype: int64

# %%
# formatting  ['PoolQC'] to Hirachial value 
train_df['PoolQC'] = train_df['PoolQC'].replace({'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('PoolQC')
# Out:
# PoolQC
# 3.0    3
# 4.0    2
# 1.0    2
# dtype: int64

# %%
# formatting  ['Fence'] to Hirachial value 
train_df['Fence'] = train_df['Fence'].replace({'GdPrv': 4, 'MnPrv': 3, 'GdWo': 2, 'MnWw': 1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('Fence')
# Out:
# Fence
# 3.0    157
# 4.0     59
# 2.0     54
# 1.0     11
# dtype: int64

# %%
# pd.get_dummies(train_df.ExterQual, prefix = 'ExterQual').iloc[:, 1:]

# %%
# train_df = pd.concat([train_df, MSZoning_dummies], axis = 1)
# train_df.head()

# %%
train_df.to_csv(r'F:/keggle/Cleaned_data/train_converted_df.csv', index = False)
